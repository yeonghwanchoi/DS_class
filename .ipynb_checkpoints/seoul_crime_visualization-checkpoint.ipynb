# %%
crime_raw_data=pd.read_csv("/Users/yeonghwanchoi/Documents/git/DS_class/data/seoul_crime/2017년.csv",encoding='euc-kr')
crime_raw_data.head()
# Out:
#    구분  죄종 발생검거   건수
# 0  중부  살인   발생    0
# 1  중부  살인   검거    0
# 2  중부  강도   발생    6
# 3  중부  강도   검거    6
# 4  중부  강간   발생  173

# %%
#rename korean named columns to english 
crime_raw_data=crime_raw_data.rename(columns={"구분":'class',"죄종":'crime_name',"발생검거":'result',"건수":'count'})
crime_raw_data
# Out:
#     class crime_name result  count
# 0      중부         살인     발생      0
# 1      중부         살인     검거      0
# 2      중부         강도     발생      6
# 3      중부         강도     검거      6
# 4      중부         강간     발생    173
# ..    ...        ...    ...    ...
# 305    수서         강간     검거    130
# 306    수서         절도     발생   1061
# 307    수서         절도     검거    596
# 308    수서         폭력     발생   1727
# 309    수서         폭력     검거   1469
#
# [310 rows x 4 columns]

# %%
#rename korean named data to english 
class_key_name=list(crime_raw_data["class"].unique())
class_key_name
# Out:
# ['중부',
#  '종로',
#  '남대문',
#  '서대문',
#  '혜화',
#  '용산',
#  '성북',
#  '동대문',
#  '마포',
#  '영등포',
#  '성동',
#  '동작',
#  '광진',
#  '서부',
#  '강북',
#  '금천',
#  '중랑',
#  '강남',
#  '관악',
#  '강서',
#  '강동',
#  '종암',
#  '구로',
#  '서초',
#  '양천',
#  '송파',
#  '노원',
#  '방배',
#  '은평',
#  '도봉',
#  '수서']

# %%
class_value_names=["Jungbu","Jongno","Namdaemoon", "Seodaemun", "Hyehwa", "Yongsan", "Seongbuk", "Dongdaemun", "Mapo", "Yeongdeungpo", "Seongdong", "Dongjak", "Gwangjin", "Seobu", "Gangbuk", "Geumcheon", "Jungnang", "Gangnam","Gwanak", "Gangseo", "Gangdong","Jongam", "Guro","Seocho", "Yangcheon", "Songpa","Nowon", "Bangbae", "Eunpyeong","Dobong","Suseo"]
class_dict=dict(zip(class_key_name,class_value_names))
class_dict
# Out:
# {'중부': 'Jungbu',
#  '종로': 'Jongno',
#  '남대문': 'Namdaemoon',
#  '서대문': 'Seodaemun',
#  '혜화': 'Hyehwa',
#  '용산': 'Yongsan',
#  '성북': 'Seongbuk',
#  '동대문': 'Dongdaemun',
#  '마포': 'Mapo',
#  '영등포': 'Yeongdeungpo',
#  '성동': 'Seongdong',
#  '동작': 'Dongjak',
#  '광진': 'Gwangjin',
#  '서부': 'Seobu',
#  '강북': 'Gangbuk',
#  '금천': 'Geumcheon',
#  '중랑': 'Jungnang',
#  '강남': 'Gangnam',
#  '관악': 'Gwanak',
#  '강서': 'Gangseo',
#  '강동': 'Gangdong',
#  '종암': 'Jongam',
#  '구로': 'Guro',
#  '서초': 'Seocho',
#  '양천': 'Yangcheon',
#  '송파': 'Songpa',
#  '노원': 'Nowon',
#  '방배': 'Bangbae',
#  '은평': 'Eunpyeong',
#  '도봉': 'Dobong',
#  '수서': 'Suseo'}

# %%
crime_name_dict=list(crime_raw_data["crime_name"].unique())
crime_name
# Out:
# ['살인', '강도', '강간', '절도', '폭력']

# %%
crime_name_dict=dict(zip(crime_name,["merder","burglar","rape","theft","violence"]))
crime_name_dict
# Out:
# {'살인': 'merder',
#  '강도': 'burglar',
#  '강간': 'rape',
#  '절도': 'theft',
#  '폭력': 'violence'}

# %%
crime_result_dict={"발생":"incident","검거":"arrest"}

# %%
input_list=[class_dict,crime_name_dict,crime_result_dict]
columns=crime_raw_data.columns

# %%
for i, dicts in enumerate(input_list):
    crime_raw_data[columns[i]]=crime_raw_data[columns[i]].replace(dicts)

# %%
crime_raw_data
# Out:
#       class crime_name    result  count
# 0    Jungbu     merder  incident      0
# 1    Jungbu     merder    arrest      0
# 2    Jungbu    burglar  incident      6
# 3    Jungbu    burglar    arrest      6
# 4    Jungbu       rape  incident    173
# ..      ...        ...       ...    ...
# 305   Suseo       rape    arrest    130
# 306   Suseo      theft  incident   1061
# 307   Suseo      theft    arrest    596
# 308   Suseo   violence  incident   1727
# 309   Suseo   violence    arrest   1469
#
# [310 rows x 4 columns]

# %%
#no null data
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   class       310 non-null    object
#  1   crime_name  310 non-null    object
#  2   result      310 non-null    object
#  3   count       310 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 9.8+ KB

# %%
#pivot_table
#use pivot_table to reform the dataframe sorted by class
crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index=["class"], columns=["crime_name","result"], aggfunc=[np.sum])
crime_station.head(2)
# Out:
#                sum                                                           \
#              count
# crime_name burglar          merder            rape           theft
# result      arrest incident arrest incident arrest incident arrest incident
# class
# Bangbae          5        4      2        1     60       65    176      364
# Dobong           3        3      1        1    115      104    417      633
#
#
#
# crime_name violence
# result       arrest incident
# class
# Bangbae         466      515
# Dobong         1116     1258

# %%
crime_station.columns
# Out:
# MultiIndex([('sum', 'count',  'burglar',   'arrest'),
#             ('sum', 'count',  'burglar', 'incident'),
#             ('sum', 'count',   'merder',   'arrest'),
#             ('sum', 'count',   'merder', 'incident'),
#             ('sum', 'count',     'rape',   'arrest'),
#             ('sum', 'count',     'rape', 'incident'),
#             ('sum', 'count',    'theft',   'arrest'),
#             ('sum', 'count',    'theft', 'incident'),
#             ('sum', 'count', 'violence',   'arrest'),
#             ('sum', 'count', 'violence', 'incident')],
#            names=[None, None, 'crime_name', 'result'])

# %%
#simplify the dataframe's columns
crime_station.columns = crime_station.columns.droplevel([0,1])

# %%
crime_station.columns
# Out:
# MultiIndex([( 'burglar',   'arrest'),
#             ( 'burglar', 'incident'),
#             (  'merder',   'arrest'),
#             (  'merder', 'incident'),
#             (    'rape',   'arrest'),
#             (    'rape', 'incident'),
#             (   'theft',   'arrest'),
#             (   'theft', 'incident'),
#             ('violence',   'arrest'),
#             ('violence', 'incident')],
#            names=['crime_name', 'result'])

# %%
crime_station.head(1)
# Out:
# crime_name burglar          merder            rape           theft           \
# result      arrest incident arrest incident arrest incident arrest incident
# class
# Bangbae          5        4      2        1     60       65    176      364
#
# crime_name violence
# result       arrest incident
# class
# Bangbae         466      515

# %%
#fame sorted by burglar and arrest
crime_station["theft","arrest"].head()
# Out:
# class
# Bangbae        176
# Dobong         417
# Dongdaemun    1017
# Dongjak        593
# Eunpyeong      559
# Name: (theft, arrest), dtype: int64

# %%
#fame sorted by murder and number
crime_station["merder","incident"].head()
# Out:
# class
# Bangbae        1
# Dobong         1
# Dongdaemun    11
# Dongjak        1
# Eunpyeong      3
# Name: (merder, incident), dtype: int64

# %%
crime_station.columns.get_level_values(0)
# Out:
# Index(['burglar', 'burglar', 'merder', 'merder', 'rape', 'rape', 'theft',
#        'theft', 'violence', 'violence'],
#       dtype='object', name='crime_name')

# %%
crime_station.columns.get_level_values(1)
# Out:
# Index(['arrest', 'incident', 'arrest', 'incident', 'arrest', 'incident',
#        'arrest', 'incident', 'arrest', 'incident'],
#       dtype='object', name='result')

# %%
# inlining the columns simply  
tmp = crime_station.columns.get_level_values(0)+"_"+crime_station.columns.get_level_values(1)
tmp
# Out:
# Index(['burglar_arrest', 'burglar_incident', 'merder_arrest',
#        'merder_incident', 'rape_arrest', 'rape_incident', 'theft_arrest',
#        'theft_incident', 'violence_arrest', 'violence_incident'],
#       dtype='object')

# %%
crime_station.columns = tmp
crime_station.head()
# Out:
#             burglar_arrest  burglar_incident  merder_arrest  merder_incident  \
# class
# Bangbae                  5                 4              2                1
# Dobong                   3                 3              1                1
# Dongdaemun               5                 3             10               11
# Dongjak                  9                 7              1                1
# Eunpyeong                2                 2              3                3
#
#             rape_arrest  rape_incident  theft_arrest  theft_incident  \
# class
# Bangbae              60             65           176             364
# Dobong              115            104           417             633
# Dongdaemun          149            165          1017            1547
# Dongjak             173            396           593            1226
# Eunpyeong           134            137           559             834
#
#             violence_arrest  violence_incident
# class
# Bangbae                 466                515
# Dobong                 1116               1258
# Dongdaemun             2093               2249
# Dongjak                1466               1700
# Eunpyeong              1206               1352

# %% [markdown]
# ### 1. how often have the viorent crimes occurred in each area?

# %%
# index is consisting of stations
crime_station.index
# Out:
# Index(['Bangbae', 'Dobong', 'Dongdaemun', 'Dongjak', 'Eunpyeong', 'Gangbuk',
#        'Gangdong', 'Gangnam', 'Gangseo', 'Geumcheon', 'Guro', 'Gwanak',
#        'Gwangjin', 'Hyehwa', 'Jongam', 'Jongno', 'Jungbu', 'Jungnang', 'Mapo',
#        'Namdaemoon', 'Nowon', 'Seobu', 'Seocho', 'Seodaemun', 'Seongbuk',
#        'Seongdong', 'Songpa', 'Suseo', 'Yangcheon', 'Yeongdeungpo', 'Yongsan'],
#       dtype='object', name='class')

# %%
#not all the stations represent the area where these are located in
#match the stations with its areas  
station_name=["Hyehwa","namdaemoon","Jungbu","Jongam","Seobu","Bangbae","Suseo"]
gu_name = ["jongno","Jungbu","Jungbu","Seongbuk","Eunpyeong","Seocho","Gangnam"]

# %%
tmp_gu=[]
for idx, _ in crime_station.iterrows():
    if idx in station_name:
        tmp_gu.append(gu_name[station_name.index(idx)])
    else:
        tmp_gu.append(idx)

# %%
#add new area column
crime_station["area"]= tmp_gu
crime_station.head(2)
# Out:
#          burglar_arrest  burglar_incident  merder_arrest  merder_incident  \
# class
# Bangbae               5                 4              2                1
# Dobong                3                 3              1                1
#
#          rape_arrest  rape_incident  theft_arrest  theft_incident  \
# class
# Bangbae           60             65           176             364
# Dobong           115            104           417             633
#
#          violence_arrest  violence_incident    area
# class
# Bangbae              466                515  Seocho
# Dobong              1116               1258  Dobong

# %%
#new dataframe sorted by area
crime_area = pd.pivot_table(crime_station, index="area", aggfunc=np.sum)
crime_area.head()
# Out:
#             burglar_arrest  burglar_incident  merder_arrest  merder_incident  \
# area
# Dobong                   3                 3              1                1
# Dongdaemun               5                 3             10               11
# Dongjak                  9                 7              1                1
# Eunpyeong                4                 4              6                6
# Gangbuk                  5                 7              8                8
#
#             rape_arrest  rape_incident  theft_arrest  theft_incident  \
# area
# Dobong              115            104           417             633
# Dongdaemun          149            165          1017            1547
# Dongjak             173            396           593            1226
# Eunpyeong           213            230           934            1387
# Gangbuk             153            208           635            1014
#
#             violence_arrest  violence_incident
# area
# Dobong                 1116               1258
# Dongdaemun             2093               2249
# Dongjak                1466               1700
# Eunpyeong              2050               2256
# Gangbuk                2023               2156

# %%
#crime arrest rates columns on dataframe
arrest=["rape_arrest","burglar_arrest","merder_arrest","theft_arrest","violence_arrest"]
occurs=["rape_incident","burglar_incident","merder_incident","theft_incident","violence_incident"]
new_columns=["rape_arrest_rate","burglar_arrest_rate","merder_arrest_rate","theft_arrest_rate","violence_arrest_rate"]
crime_area[new_columns]=crime_area[occurs]/(crime_area[arrest].values)*100
crime_area.head()
# Out:
#             burglar_arrest  burglar_incident  merder_arrest  merder_incident  \
# area
# Dobong                   3                 3              1                1
# Dongdaemun               5                 3             10               11
# Dongjak                  9                 7              1                1
# Eunpyeong                4                 4              6                6
# Gangbuk                  5                 7              8                8
#
#             rape_arrest  rape_incident  theft_arrest  theft_incident  \
# area
# Dobong              115            104           417             633
# Dongdaemun          149            165          1017            1547
# Dongjak             173            396           593            1226
# Eunpyeong           213            230           934            1387
# Gangbuk             153            208           635            1014
#
#             violence_arrest  violence_incident  rape_arrest_rate  \
# area
# Dobong                 1116               1258         90.434783
# Dongdaemun             2093               2249        110.738255
# Dongjak                1466               1700        228.901734
# Eunpyeong              2050               2256        107.981221
# Gangbuk                2023               2156        135.947712
#
#             burglar_arrest_rate  merder_arrest_rate  theft_arrest_rate  \
# area
# Dobong               100.000000               100.0         151.798561
# Dongdaemun            60.000000               110.0         152.114061
# Dongjak               77.777778               100.0         206.745363
# Eunpyeong            100.000000               100.0         148.501071
# Gangbuk              140.000000               100.0         159.685039
#
#             violence_arrest_rate
# area
# Dobong                112.724014
# Dongdaemun            107.453416
# Dongjak               115.961801
# Eunpyeong             110.048780
# Gangbuk               106.574394

# %%
crime_area= crime_area.drop(arrest,axis=1)
crime_area[crime_area[new_columns]>100]=100

# %%
#rename columns 
crime_area.rename(columns={
    "rape_incident" : "rape",
    "theft_incident" : "theft",
    "merder_incident" : "merder",
    "burglar_incident" : "burglar",
    "violence_incident" : "violence"},
    inplace = True)

# %%
crime_area.head()
# Out:
#             burglar  merder  rape  theft  violence  rape_arrest_rate  \
# area
# Dobong            3       1   104    633      1258         90.434783
# Dongdaemun        3      11   165   1547      2249        100.000000
# Dongjak           7       1   396   1226      1700        100.000000
# Eunpyeong         4       6   230   1387      2256        100.000000
# Gangbuk           7       8   208   1014      2156        100.000000
#
#             burglar_arrest_rate  merder_arrest_rate  theft_arrest_rate  \
# area
# Dobong               100.000000               100.0              100.0
# Dongdaemun            60.000000               100.0              100.0
# Dongjak               77.777778               100.0              100.0
# Eunpyeong            100.000000               100.0              100.0
# Gangbuk              100.000000               100.0              100.0
#
#             violence_arrest_rate
# area
# Dobong                     100.0
# Dongdaemun                 100.0
# Dongjak                    100.0
# Eunpyeong                  100.0
# Gangbuk                    100.0

# %%
#normalization 
col=["merder","burglar","rape","theft","violence"]
col2= ["merder_arrest_rate","burglar_arrest_rate","rape_arrest_rate","theft_arrest_rate","violence_arrest_rate"]

crime_area_norm = crime_area[col] / crime_area[col].max()
crime_area_norm[col2]= crime_area[col2]
crime_area_norm.head()
# Out:
#               merder  burglar      rape     theft  violence  \
# area
# Dobong      0.066667     0.15  0.171334  0.202236  0.317998
# Dongdaemun  0.733333     0.15  0.271829  0.494249  0.568504
# Dongjak     0.066667     0.35  0.652389  0.391693  0.429727
# Eunpyeong   0.400000     0.20  0.378913  0.443131  0.570273
# Gangbuk     0.533333     0.35  0.342669  0.323962  0.544995
#
#             merder_arrest_rate  burglar_arrest_rate  rape_arrest_rate  \
# area
# Dobong                   100.0           100.000000         90.434783
# Dongdaemun               100.0            60.000000        100.000000
# Dongjak                  100.0            77.777778        100.000000
# Eunpyeong                100.0           100.000000        100.000000
# Gangbuk                  100.0           100.000000        100.000000
#
#             theft_arrest_rate  violence_arrest_rate
# area
# Dobong                  100.0                 100.0
# Dongdaemun              100.0                 100.0
# Dongjak                 100.0                 100.0
# Eunpyeong               100.0                 100.0
# Gangbuk                 100.0                 100.0

# %%
crime_area_norm["crime"] = np.mean(crime_area_norm[col],axis=1)
crime_area_norm.head()
# Out:
#               merder  burglar      rape     theft  violence  \
# area
# Dobong      0.066667     0.15  0.171334  0.202236  0.317998
# Dongdaemun  0.733333     0.15  0.271829  0.494249  0.568504
# Dongjak     0.066667     0.35  0.652389  0.391693  0.429727
# Eunpyeong   0.400000     0.20  0.378913  0.443131  0.570273
# Gangbuk     0.533333     0.35  0.342669  0.323962  0.544995
#
#             merder_arrest_rate  burglar_arrest_rate  rape_arrest_rate  \
# area
# Dobong                   100.0           100.000000         90.434783
# Dongdaemun               100.0            60.000000        100.000000
# Dongjak                  100.0            77.777778        100.000000
# Eunpyeong                100.0           100.000000        100.000000
# Gangbuk                  100.0           100.000000        100.000000
#
#             theft_arrest_rate  violence_arrest_rate     crime
# area
# Dobong                  100.0                 100.0  0.181647
# Dongdaemun              100.0                 100.0  0.443583
# Dongjak                 100.0                 100.0  0.378095
# Eunpyeong               100.0                 100.0  0.398463
# Gangbuk                 100.0                 100.0  0.418992

# %%
crime_area_norm["arrest"] = np.mean(crime_gu_norm[col2],axis=1)
crime_area_norm.head()
# Out:
#               merder  burglar      rape     theft  violence  \
# area
# Dobong      0.066667     0.15  0.171334  0.202236  0.317998
# Dongdaemun  0.733333     0.15  0.271829  0.494249  0.568504
# Dongjak     0.066667     0.35  0.652389  0.391693  0.429727
# Eunpyeong   0.400000     0.20  0.378913  0.443131  0.570273
# Gangbuk     0.533333     0.35  0.342669  0.323962  0.544995
#
#             merder_arrest_rate  burglar_arrest_rate  rape_arrest_rate  \
# area
# Dobong                   100.0           100.000000         90.434783
# Dongdaemun               100.0            60.000000        100.000000
# Dongjak                  100.0            77.777778        100.000000
# Eunpyeong                100.0           100.000000        100.000000
# Gangbuk                  100.0           100.000000        100.000000
#
#             theft_arrest_rate  violence_arrest_rate     crime      arrest
# area
# Dobong                  100.0                 100.0  0.181647   98.086957
# Dongdaemun              100.0                 100.0  0.443583   92.000000
# Dongjak                 100.0                 100.0  0.378095   95.555556
# Eunpyeong               100.0                 100.0  0.398463  100.000000
# Gangbuk                 100.0                 100.0  0.418992  100.000000

# %% [markdown]
# ### visualization

# %%
plt.rc('font', family='AppleGothic')

# %%
target_col=["rape_arrest_rate","burglar_arrest_rate","merder_arrest_rate","violence_arrest_rate","theft_arrest_rate","arrest"]
crime_area_norm_sort= crime_area_norm.sort_values("arrest",ascending=False)
plt.figure(figsize=(10,10))
sns.heatmap(crime_area_norm_sort[target_col], annot=True, fmt="f", linewidths=.5,cmap="RdBu")
plt.title("crime arrest rates columns")
plt.show()

# %%
target_col1=["rape","theft","murder","burglar","violence","crime"]
crime_area_norm_sort= crime_area_norm.sort_values("crime",ascending=False)
plt.figure(figsize=(10,10))
sns.heatmap(crime_area_norm_sort[target_col], annot=True, fmt="f", linewidths=.5,cmap="RdPu")
plt.title("crime arrest rates columns")
plt.show()

# %%
# Out:
# area
# Dobong          0.066667
# Dongdaemun      0.733333
# Dongjak         0.066667
# Eunpyeong       0.400000
# Gangbuk         0.533333
# Gangdong        0.333333
# Gangnam         0.466667
# Gangseo         0.733333
# Geumcheon       0.333333
# Guro            0.466667
# Gwanak          0.533333
# Gwangjin        0.400000
# Jongno          0.333333
# Jungbu          0.000000
# Jungnang        0.333333
# Mapo            0.200000
# Namdaemoon      0.066667
# Nowon           0.266667
# Seocho          0.600000
# Seodaemun       0.266667
# Seongbuk        0.466667
# Seongdong       0.066667
# Songpa          0.400000
# Yangcheon       0.200000
# Yeongdeungpo    1.000000
# Yongsan         0.066667
# jongno          0.133333
# Name: merder, dtype: float64
