# %%
import nltk
from konlpy.tag import Kkma

# %%
from konlpy.corpus import kobill 
files_ko = kobill.fileids()
doc_ko = kobill.open("1809890.txt").read()
name='대한민국 국회 의안 제 1809890호'

# %%
from konlpy.tag import Okt; t = Okt()
tokens_ko = t.nouns(doc_ko)
tokens_ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '의',
#  '안',
#  '번',
#  '호',
#  '발의',
#  '연월일',
#  '발',
#  '의',
#  '자',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '만',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '안',
#  '제',
#  '항제',
#  '호',
#  '법률',
#  '제',
#  '호',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '호',
#  '중',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '만',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
# ...

# %%
ko = nltk.Text(tokens_ko, name='대한민국 국회 의안 제 1809890호')
print(len(ko.tokens)), print(len(set(ko.tokens))),ko.vocab()
# Out:
# 735
# 250
# (None,
#  None,
#  FreqDist({'육아휴직': 38, '발생': 19, '만': 18, '이하': 18, '비용': 17, '액': 17, '경우': 16, '세': 16, '자녀': 14, '고용': 14, ...}))

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

plt.rcParams['axes.unicode_minus']=False
f_path = "/Users/yeonghwanchoi/Documents/D2Coding-all.ttc"

plt.rc('font', family='AppleGothic')
plt.figure(figsize=(12,6))
ko.plot(50)

# %%
stop_words = ['.',"(",")",',',"''", '%', '-', 'X', ').','x', '의', '자',
             '에', '안','번', '호', '을', '이', '다', '만', '로', '가', '를']
ko = [each_word for each_word in ko if each_word not in stop_words]
ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '발의',
#  '연월일',
#  '발',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '제',
#  '항제',
#  '법률',
#  '제',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '중',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '말',
#  '자녀',
#  '부',
#  '칙',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '신',
#  '구조',
#  '문대비',
#  '표',
#  '현',
# ...

# %%
#빈도 다시 그리기
ko = nltk.Text(ko, name)
plt.figure(figsize=(12,6))
ko.plot(50)

# %%
ko.count('초등학교')
# Out:
# 6

# %%
# 문장내 특정 단어 위치
plt.figure(figsize=(12,6))
ko.dispersion_plot(['육아휴직', '초등학교', '공무원'])

# %%
#주변에 나열된 단어
ko.concordance('초등학교')
# Out:
# Displaying 6 of 6 matches:
#  안규백 황영철 박영아 김정훈 김학송 의원 인 제안 이유 및 내용 초등학교 저학년 경우 부모 사랑 필요 나이 현재 공무원 자녀 양육 위 육아
#  나이 현재 공무원 자녀 양육 위 육아휴직 수 자녀 나이 세 이하 초등학교 저학년 자녀 위 해당 부모님 일자리 곧 출산 의욕 저하 문제 수
# 일부 개정 법률 지방공무원법 일부 다음 개정 제 항제 중 세 이하 초등학교 취학 전 자녀 세 이하 취학 중인 경우 초등학교 학년 이하 말 자
# 항제 중 세 이하 초등학교 취학 전 자녀 세 이하 취학 중인 경우 초등학교 학년 이하 말 자녀 부 칙 법 공포 날 시행 신 구조 문대비 표
#  수 다만 제 경우 대통령령 정 사정 직 명 생 략 현행 세 이하 초등학교 취 세 이하 취학 중인 경우 학 전 자녀 양육 위 초등학교 학년
#  이하 초등학교 취 세 이하 취학 중인 경우 학 전 자녀 양육 위 초등학교 학년 이하 여 여자 공무원 말 자녀 임신 출산 때 생 략 생 략

# %%
from wordcloud import WordCloud
data = ko.vocab().most_common(200)
plt.rc('font', family='AppleGothic')
wordcloud = WordCloud(font_path = f_path, relative_scaling = 0.2, \
                      background_color='white').generate_from_frequencies(dict(data))
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# tokenize
from nltk.tokenize import word_tokenize
import nltk
train = [('i like you', 'pos'), 
         ('i hate you', 'neg'),
        ('you like me', 'neg'),
        ('i like her', 'pos')]

# %%
all_words = set(word.lower() for sentence in train for word in word_tokenize(sentence[0]))
all_words
# Out:
# {'hate', 'her', 'i', 'like', 'me', 'you'}

# %%
t = [({word: (word in word_tokenize(x[0])) for word in all_words}, x[1]) for x in train]
clf = nltk.NaiveBayesClassifier.train(t)
clf.show_most_informative_features()
# Out:
# Most Informative Features
#                     hate = False             pos : neg    =      1.7 : 1.0
#                      her = False             neg : pos    =      1.7 : 1.0
#                        i = True              pos : neg    =      1.7 : 1.0
#                     like = True              pos : neg    =      1.7 : 1.0
#                       me = False             pos : neg    =      1.7 : 1.0
#                      you = True              neg : pos    =      1.7 : 1.0

# %%
test_sentence = 'i like Merui'
test_sent_features = {word.lower() : (word in word_tokenize(test_sentence.lower())) for word in all_words}

# %%
test_sent_features
# Out:
# {'i': True,
#  'you': False,
#  'me': False,
#  'like': True,
#  'hate': False,
#  'her': False}

# %%
clf.classify(test_sent_features)
# Out:
# 'pos'

# %%
from konlpy.tag import Okt
pos_tagger = Okt()
train=[('난 수업이 빨리 마치면 좋겠어','pos'),
      ('난 수업리 빨리 마치면 좋겠어','pos'),
      ('내일은 놀러가야지','pos'),
      ('오늘 수업은 정말 지루해','neg'),
      ('나는 왜 이런걸 해야하는지 모르겠어','neg')]

# %%
#형태소 분석
pos_tagger.pos(train[0][0])
# Out:
# [('난', 'Noun'),
#  ('수업', 'Noun'),
#  ('이', 'Josa'),
#  ('빨리', 'Adverb'),
#  ('마치', 'Noun'),
#  ('면', 'Josa'),
#  ('좋겠어', 'Adjective')]

# %%
#훈련용 데이터 형태소
train_docs= [(pos_tagger.morphs(sentence[0]), sentence[1]) for sentence in train]
train_docs
# Out:
# [(['난', '수업', '이', '빨리', '마치', '면', '좋겠어'], 'pos'),
#  (['난', '수업', '리', '빨리', '마치', '면', '좋겠어'], 'pos'),
#  (['내일', '은', '놀러', '가야', '지'], 'pos'),
#  (['오늘', '수업', '은', '정말', '지루해'], 'neg'),
#  (['나', '는', '왜', '이런', '걸', '해야하는지', '모르겠어'], 'neg')]

# %%
#말뭉치
all_words = set([t for d in train_docs for t in d[0]])
all_words
# Out:
# {'가야',
#  '걸',
#  '나',
#  '난',
#  '내일',
#  '놀러',
#  '는',
#  '리',
#  '마치',
#  '면',
#  '모르겠어',
#  '빨리',
#  '수업',
#  '오늘',
#  '왜',
#  '은',
#  '이',
#  '이런',
#  '정말',
#  '좋겠어',
#  '지',
#  '지루해',
#  '해야하는지'}

# %%
def term_exists(doc):
    return {word: (word in set(doc)) for word in all_words}

# %%
train_xy =[(term_exists(d), c) for d,c in train_docs]
train_xy
# Out:
# [({'리': False,
#    '는': False,
#    '지': False,
#    '나': False,
#    '놀러': False,
#    '좋겠어': True,
#    '내일': False,
#    '이런': False,
#    '수업': True,
#    '지루해': False,
#    '면': True,
#    '은': False,
#    '이': True,
#    '정말': False,
#    '왜': False,
#    '걸': False,
#    '모르겠어': False,
#    '해야하는지': False,
#    '가야': False,
#    '빨리': True,
#    '오늘': False,
#    '마치': True,
#    '난': True},
#   'pos'),
#  ({'리': True,
#    '는': False,
#    '지': False,
#    '나': False,
#    '놀러': False,
#    '좋겠어': True,
#    '내일': False,
#    '이런': False,
#    '수업': True,
#    '지루해': False,
#    '면': True,
#    '은': False,
#    '이': False,
#    '정말': False,
#    '왜': False,
#    '걸': False,
#    '모르겠어': False,
#    '해야하는지': False,
#    '가야': False,
#    '빨리': True,
#    '오늘': False,
#    '마치': True,
#    '난': True},
#   'pos'),
#  ({'리': False,
#    '는': False,
#    '지': True,
#    '나': False,
#    '놀러': True,
#    '좋겠어': False,
#    '내일': True,
#    '이런': False,
#    '수업': False,
# ...

# %%
clf = nltk.NaiveBayesClassifier.train(train_xy)
clf.show_most_informative_features()
# Out:
# Most Informative Features
#                        난 = False             neg : pos    =      2.2 : 1.0
#                       마치 = False             neg : pos    =      2.2 : 1.0
#                        면 = False             neg : pos    =      2.2 : 1.0
#                       빨리 = False             neg : pos    =      2.2 : 1.0
#                      좋겠어 = False             neg : pos    =      2.2 : 1.0
#                        걸 = False             pos : neg    =      1.8 : 1.0
#                        나 = False             pos : neg    =      1.8 : 1.0
#                        는 = False             pos : neg    =      1.8 : 1.0
#                     모르겠어 = False             pos : neg    =      1.8 : 1.0
#                       오늘 = False             pos : neg    =      1.8 : 1.0

# %%
test_sentence = '수업 마치면 놀러가야지'
test_docs = pos_tagger.morphs(test_sentence)
test_docs
# Out:
# ['수업', '마치', '면', '놀러', '가야', '지']

# %%
test_xy = term_exists(test_docs)
test_xy
# Out:
# {'리': False,
#  '는': False,
#  '지': True,
#  '나': False,
#  '놀러': True,
#  '좋겠어': False,
#  '내일': False,
#  '이런': False,
#  '수업': True,
#  '지루해': False,
#  '면': True,
#  '은': False,
#  '이': False,
#  '정말': False,
#  '왜': False,
#  '걸': False,
#  '모르겠어': False,
#  '해야하는지': False,
#  '가야': True,
#  '빨리': False,
#  '오늘': False,
#  '마치': True,
#  '난': False}
